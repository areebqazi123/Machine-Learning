# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
ipl_auction_df= pd.read_csv('IPL IMB381IPL2013.csv')

sn.barplot(x='AGE',y='SOLD PRICE', data = ipl_auction_df)
# Out:
# <Axes: xlabel='AGE', ylabel='SOLD PRICE'>

# %%
sn.barplot(x='AGE',y='SOLD PRICE',hue='PLAYING ROLE', data = ipl_auction_df)
# Out:
# <Axes: xlabel='AGE', ylabel='SOLD PRICE'>

# %%
plt.hist( ipl_auction_df['SOLD PRICE'] )

# %%
plt.hist( ipl_auction_df['SOLD PRICE'],bins=20 )
# Out:
# (array([16., 11., 16., 16.,  9., 12.,  5., 15.,  8.,  6.,  6.,  1.,  0.,
#          0.,  1.,  0.,  1.,  3.,  0.,  4.]),
#  array([  20000.,  109000.,  198000.,  287000.,  376000.,  465000.,
#          554000.,  643000.,  732000.,  821000.,  910000.,  999000.,
#         1088000., 1177000., 1266000., 1355000., 1444000., 1533000.,
#         1622000., 1711000., 1800000.]),
#  <BarContainer object of 20 artists>)

# %%
sn.distplot( ipl_auction_df['SOLD PRICE'] )
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_16236\3110235523.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot( ipl_auction_df['SOLD PRICE'] )
# <Axes: xlabel='SOLD PRICE', ylabel='Density'>

# %%
sn.boxplot(ipl_auction_df['SOLD PRICE']);

# %%
sn.distplot (ipl_auction_df[ipl_auction_df['CAPTAINCY EXP'] == 1]['SOLD PRICE'],  color = 'y',  
label = 'Captaincy Experience')
sn.distplot (ipl_auction_df[ipl_auction_df['CAPTAINCY EXP'] == 0]['SOLD PRICE'],  color = 'r',  
label = 'No Captaincy Experience')
plt.legend()
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_16236\159497652.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot (ipl_auction_df[ipl_auction_df['CAPTAINCY EXP'] == 1]['SOLD PRICE'],  color = 'y',
# C:\Users\areeb\AppData\Local\Temp\ipykernel_16236\159497652.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot (ipl_auction_df[ipl_auction_df['CAPTAINCY EXP'] == 0]['SOLD PRICE'],  color = 'r',

# %%
sn.boxplot(x =  'PLAYING ROLE', y = 'SOLD PRICE',  
data = ipl_auction_df)
# Out:
# <Axes: xlabel='PLAYING ROLE', ylabel='SOLD PRICE'>

# %%
ipl_batsman_df =  ipl_auction_df[ipl_auction_df['PLAYING ROLE'] == 'Batsman']
plt.scatter( x = ipl_batsman_df['SIXERS'], y = ipl_batsman_df['SOLD PRICE'])

# %%
sn.regplot(  x = 'SIXERS',  y = 'SOLD PRICE',  data = ipl_batsman_df )
# Out:
# <Axes: xlabel='SIXERS', ylabel='SOLD PRICE'>

# %%
influential_features	=	['SR-B',	'AVE',	'SIXERS',	'SOLD PRICE']
sn.pairplot(ipl_auction_df[influential_features],	height=1)

# %%
ipl_auction_df[influential_features].corr()
# Out:
#                 SR-B       AVE    SIXERS  SOLD PRICE
# SR-B        1.000000  0.583579  0.425394    0.184278
# AVE         0.583579  1.000000  0.705365    0.396519
# SIXERS      0.425394  0.705365  1.000000    0.450609
# SOLD PRICE  0.184278  0.396519  0.450609    1.000000

# %%
sn.heatmap(ipl_auction_df[influential_features].corr(),	annot=True)
# Out:
# <Axes: >
